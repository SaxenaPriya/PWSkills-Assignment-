# %% [markdown]
# # **OOPs Assignments**
# **Theory Questions**

# %% [markdown]
# Q1. What is Object-Oriented Programming (OOP)?
# - Object-Oriented Programming is a computer programming language that uses objects in programing
# - It focuses on classes and objects instead of only functions.
# - It aims to bind data and function together that operate on them so that, it can't be accessed outside.
# - It helps in organizing code, reusing it, and making large programs easier to manage.
# - It implement real-world entities like inheritance, hiding, polymorphism, etc in programming.
#
# Q2. What is a class in OOP?
# - Class is a user-defined data type in OOPs. It consists of variables(data) and method (functions), which can be accessed and used by creating an instance of that class.
# - It is like an blueprint or template which create objects.
# *Syntax:*
# ```
# class ClassName():
#   # class body (attributes and methods)
# ```
# Q3. What is an object in OOP?
# - An object is a real instance created from a class. It represents actual data and helps access the methods of the class.
# *Syntax:*
# ```
# Obj = ClassName()
# ```
# Q4. What is the difference between abstraction and encapsulation?
# - Abstraction means hiding unnecessary details and showing only essential features.
# - Encapsulation means wrapping data and methods inside a class and protecting data from misuse.
# - Both of them are one the core concept of OOP where, abstraction focuses on design and encapsulation focuses on implementation.
#
# Q5. What are dunder methods in Python?
# - Dunder methods are special methods with name starting and ending with double underscores. They help in customise how objects behave with built-in operations.
# *Example:*
# ```
# __init__, ___str__, etc.
# ```
#
# Q6. Explain the concept of inheritance in OOP.
# - Inheritance is a concept of OOP, which allows one class(parent/derived) to use the properties and methods of another class(parent). It promotes code reuse and reduces duplication.
# *Syntax:*
# ```
# class ChildClass(ParentClass):
#  ```
#
# Q7. What is polymorphism in OOP?
# - Polymorphism means many forms that allows multiple classes to have same name but with the different methods and behaviour.
# - It allows for more flexible, reusable, and maintainable code.
# - It has the ability to make same operator or method work differently on the basis of data passed.
# *Example:*
# ```
# def func(a, b):
#     return a + b
# func(2, 3) #Output: 5
# func("Hello", "World") #Output: Hello World
# ```
#
# Q8. How is encapsulation achieved in Python?
# - Encapsulation is achieved using classes and access modifiers.
# To declare a method or a variable as private or protected we need to use underscores("_' or "__") before the name of it.
# *Example:*
# ```
# def __private_method(self, name): #private method
#   self.__name = name #private variable
# ```
# Q9. What is a constructor in Python?
# - A constructor is a special method that runs automatically when an object is created.
# - It is used to initialize object data.
# *Syntax:*
#
# ```
# def __init__(self):
# ```
#
# Q10. What are class and static methods in Python?
# - Class methods work with class variables and use cls as its first argument. It can access or modify the class attributes and methods, in away that can affect all the class instances.
# *Syntax:*
#
# ```
# @classmethod
# def method(cls):
# ```
# - Static methods do not use class data or instance, they just happen to live inside a class namespace. It doesn't receive self or cls ,as first agrument and cannot modify instance or class.
# *Syntax:*
#
# ```
# @staticmethod
# def method():
# ```
# Q11. What is method overloading in Python?
# - Method overloading involves having multiple methods in the same class with the same name but different parameters.
# - Python does not support method overloading directly. It is handled using default parameters or *args.
# *Example:*

# %%
# method overloading
class Student:
  def student(self, name = ""):
    print("this is a student", name)
stud = Student()
stud.student()
stud.student("Prerit")
# Out:
# this is a student
# this is a student Prerit

# %% [markdown]
# Q12. What is method overriding in OOP?
# - Method overriding happens when a child class provides its own version of a parent method, enabling runtime polymorphism.
# - The child must have the same name and parameters as the parent class method. It is used to change inherited behavior of a class.
# - It uses super() function to access the parent class's method within the overridden method.

# %%
#method overriding
class teacher:
  def lecture(self):
    print("this is a teacher lecture")
class student(teacher):
  def lecture(self):
    print("this is a student lecture")

teach = teacher()
teach.lecture()
stud = student()
stud.lecture()
# Out:
# this is a teacher lecture
# this is a student lecture

# %% [markdown]
# Q13. What is a property decorator in Python?
# The @property decorator is a built-in function that allows a method to be accessed like a variable.
# - It is used for controlled data access and logic without breaking the simple way of attribute access.
# ```
# @property
# def method(self):
# ```
#
# Q14. Why is polymorphism important in OOP?
# - It improves flexibility and code reusability.
# - It reduces complexity in large applications.
#
# Q15. What is an abstract class in Python?
# - An abstract class contains one or more abstract methods. It is used as a base class and cannot be instantiated directly.
# - Focuses on what a class should do rather than how it does it. Uses @abstractmethod decorater.
#
# Q16. What are the advantages of OOP?
# - Code reusability
# - Easy maintenance
# - Better structure
# - Real-world modeling
#
# Q17. What is the difference between a class variable and an instance variable?
# - Class variables are shared by all objects.
#
# - Instance variables are unique to each object.
#
# Q18. What is Multiple Inheritance in Python?
# - Multiple inheritance allows a class to inherit from more than one parent class.
# - It is one the type of Inheritance supported by python.
# *Syntax:*
# ```
# class Child(Parent1, Parent2):
#     pass
# ```
#
# Q19.  Explain the purpose of ‘’__ str __’ and ‘__ repr __’ ‘ methods in Python.
#
# - __ str __ -  User-friendly string (used by print())
#
# - __ repr __ - Developer-friendly, unambiguous representation
# *Example:*

# %%
class Book:
    def __init__(self, title):
        self.title = title

    def __str__(self):
        return self.title

    def __repr__(self):
        return f"Book('{self.title}')"

b = Book("Harry Potter")
print(b)
b.__str__()
b.__repr__()
# Out:
# Harry Potter
# "Book('Harry Potter')"

# %% [markdown]
# Q20. What is the significance of the ‘super()’ function in Python?
# - super() is used to call methods of the parent class, especially in inheritance.
#
# Q21. What is the significance of the __del__ method in Python?
# - __del__ is a destructor called when an object is about to be destroyed.
# *Syntax:*
# ```
# def __ del __():
#   pass
#   ```
# Q22. What is the difference between @staticmethod and @classmethod in Python?
# - @staticmethod
#
# -- Does not receive self or cls
#
# -- Cannot access or modify class variables directly
#
# -- Works like a normal function but is placed inside a class
#
# -- Used for utility/helper functions related to the class
#
# - @classmethod
#
# -- Receives the class as the first parameter cls
#
# -- Can access and modify class variables
#
# -- Can be used to create alternative constructors
#
# -- Affects the class as a whole, not individual
# objects
#
#
# Q23. How does polymorphism work in Python with inheritance?
# - Polymorphism allows different classes to have methods with the same name but different behavior.
#
#
# Q24. What is method chaining in Python OOP?
# - Method chaining allows calling multiple methods on the same object in one line by returning self.
#
# *Syntax:*
#
# obj.a( ).b( )
#
# Q25. What is the purpose of the __call__ method in Python?
# - __ call __ allows an object to be called like a function.
#
# *Syntax:*
# ```
# def __ call __():
#   pass
# ```

# %%
# Q1. Create a parent class Animal with a method speak() that prints a generic message. Create a child class Dog that overrides the speak() method to print "Bark!".

class Animal:
    def speak(self):
        print("Animal makes a sound")

class Dog(Animal):
    def speak(self):
        print("Bark!")

Dog().speak()
# Out:
# Bark!

# %%
# Q2. Write a program to create an abstract class Shape with a method area(). Derive classes Circle and Rectangle from it and implement the area() method in both.

from abc import ABC, abstractmethod
import math

class Shape(ABC):
    @abstractmethod
    def area(self):
        pass

class Circle(Shape):
    def __init__(self, r):
        self.r = r
    def area(self):
        return math.pi * self.r ** 2

class Rectangle(Shape):
    def __init__(self, l, b):
        self.l = l
        self.b = b
    def area(self):
        return self.l * self.b

print(Circle(5).area())
print(Rectangle(4, 6).area())
# Out:
# 78.53981633974483
# 24

# %%
# Q3. Implement a multi-level inheritance scenario where a class Vehicle has an attribute type. Derive a class Car and further derive a class ElectricCar that adds a battery attribute.

class Vehicle:
    def __init__(self, type):
        self.type = type
        print("Type of Vehicle: ", self.type)

class Car(Vehicle):
    def __init__(self, type, brand):
        super().__init__(type)
        self.brand = brand
        print("Brand of",self.type ,"is: ", self.brand)


class ElectricCar(Car):
    def __init__(self, type, brand, battery):
        super().__init__(type, brand)
        self.battery = battery
        print("Battery of",self.brand, "is:" ,self.battery)


ec = ElectricCar("Car", "Tesla", "75 kWh")
# Out:
# Type of Vehicle:  Car
# Brand of Car is:  Tesla
# Battery of Tesla is: 75 kWh

# %%
# 4. Demonstrate polymorphism by creating a base class Bird with a method fly(). Create two derived classes Sparrow and Penguin that override the fly() method.

class Bird:
    def fly(self):
        print("Bird flies")

class Sparrow(Bird):
    def fly(self):
        print("Sparrow flies")

class Penguin(Bird):
    def fly(self):
        print("Penguin cannot fly")

for bird in (Sparrow(), Penguin()):
    bird.fly()
# Out:
# Sparrow flies
# Penguin cannot fly

# %%
# 5. Write a program to demonstrate encapsulation by creating a class BankAccount with private attributes balance and methods to deposit, withdraw, and check balance.

class BankAccount:
    def __init__(self, balance):
        self.__balance = balance

    def deposit(self, amt):
        if amt < 0:
            print("Invalid amount")
            return
        self.__balance += amt

    def withdraw(self, amt):
        if amt > self.__balance:
            print("Insufficient balance")
            return
        self.__balance -= amt

    def check_balance(self):
        return self.__balance

acc = BankAccount(1000)
acc.deposit(500)
print(acc.check_balance())
acc.deposit(-100)
acc.withdraw(1200)
print(acc.check_balance())
acc.withdraw(2000)
# Out:
# 1500
# Invalid amount
# 300
# Insufficient balance

# %%
# 6. Demonstrate runtime polymorphism using a method play() in a base class Instrument. Derive classes Guitar and Piano that implement their own version of play().

class Instrument:
    def play(self):
        pass

class Guitar(Instrument):
    def play(self):
        print("Playing Guitar")

class Piano(Instrument):
    def play(self):
        print("Playing Piano")

for i in (Guitar(), Piano()):
    i.play()
# Out:
# Playing Guitar
# Playing Piano

# %%
# 7. Create a class MathOperations with a class method add_numbers() to add two numbers and a static method subtract_numbers() to subtract two numbers.

class MathOperations:
    @classmethod
    def add_numbers(cls, a, b):
        return a + b

    @staticmethod
    def subtract_numbers(a, b):
        return a - b

print(MathOperations.add_numbers(5, 3))
print(MathOperations.subtract_numbers(5, 3))
# Out:
# 8
# 2

# %%
# 8. Implement a class Person with a class method to count the total number of persons created.

class Person:
    count = 0

    def __init__(self):
        Person.count += 1

    @classmethod
    def total_persons(cls):
        return cls.count

no_of_persons = int(input("Enter the number of persons to create: "))

for _ in range(no_of_persons):
    Person()

print(Person.total_persons())
# Out:
# Enter the number of persons to create: 33
# 33

# %%
# 9. Write a class Fraction with attributes numerator and denominator. Override the str method to display the fraction as "numerator/denominator".

class Fraction:
    def __init__(self, n, d):
        self.n = n
        self.d = d

    def __str__(self):
        return f"{self.n}/{self.d}"

print(Fraction(3, 4))
# Out:
# 3/4

# %%
# 10. Demonstrate operator overloading by creating a class Vector and overriding the add method to add two vectors.
class Vector:
    def __init__(self, x, y):
        self.x = x
        self.y = y

    def __add__(self, other):
        return Vector(self.x + other.x, self.y + other.y)

v = Vector(2, 3) + Vector(4, 5)
print("New Vector is: (",v.x,",",v.y,")")
# Out:
# New Vector is: ( 6 , 8 )

# %%
# 11. Create a class Person with attributes name and age. Add a method greet() that prints "Hello, my name is {name} and I am {age} years old."

class Person:
    def __init__(self, name, age):
        self.name = name
        self.age = age

    def greet(self):
        print(f"Hello, my name is {self.name} and I am {self.age} years old.")

Person("Prerit", 24).greet()
# Out:
# Hello, my name is Prerit and I am 24 years old.

# %%
# 12. Implement a class Student with attributes name and grades. Create a method average_grade() to compute the average of the grades.

class Student:
    def __init__(self, name, grades):
        self.name = name
        self.grades = grades

    def average_grade(self):
        return self.name,sum(self.grades) / len(self.grades)

print(Student("Hardik", [80, 90, 100]).average_grade())
# Out:
# ('Hardik', 90.0)

# %%
# 13. Create a class Rectangle with methods set_dimensions() to set the dimensions and area() to calculate the area.

class Rectangle:
    def set_dimensions(self, l, b):
        self.l = l
        self.b = b

    def area(self):
        return self.l * self.b

r = Rectangle()
r.set_dimensions(4, 5)
print(r.area())
# Out:
# 20

# %%
# 14. Create a class Employee with a method calculate_salary() that computes the salary based on hours worked and hourly rate. Create a derived class Manager that adds a bonus to the salaryCreate a class Product with attributes name, price, and quantity. Implement a method total_price() that calculates the total price of the product.

class Employee:
    def calculate_salary(self, hours, rate):
        return hours * rate

class Manager(Employee):
    def calculate_salary(self, hours, rate, bonus):
        return super().calculate_salary(hours, rate) + bonus

print(Manager().calculate_salary(40, 100, 5000))
# Out:
# 9000

# %%
# 15. Create a class Product with attributes name, price, and quantity. Implement a method total_price() that calculates the total price of the product.

class Product:
  def __init__(self, name, price, quantity):
    self.name = name
    self.price = price
    self.quantity = quantity

  def total_price(self):
    return self.price * self.quantity

print(Product("Pen", 10, 5).total_price())
# Out:
# 50

# %%
# 16. Create a class Animal with an abstract method sound(). Create two derived classes Cow and Sheep that implement the sound() method.

from abc import ABC, abstractmethod

class Animal(ABC):
    @abstractmethod
    def sound(self):
        pass

class Cow(Animal):
    def sound(self):
        print("Moo")

class Sheep(Animal):
    def sound(self):
        print("Baa")

Cow().sound()
Sheep().sound()
# Out:
# Moo
# Baa

# %%
# 17. Create a class Book with attributes title, author, and year_published. Add a method get_book_info() that returns a formatted string with the book's details.

class Book:
    def __init__(self, title, author, year_published):
        self.title = title
        self.author = author
        self.year_published = year_published

    def get_book_info(self):
        return f"{self.title} by {self.author} ({self.year_published})"

print(Book("Python", "Guido", 1991).get_book_info())
# Out:
# Python by Guido (1991)

# %%
# 18. Create a class House with attributes address and price. Create a derived class Mansion that adds an attribute number_of_rooms.

class House:
    def __init__(self, address, price):
        self.address = address
        self.price = price

class Mansion(House):
    def __init__(self, address, price, rooms):
        super().__init__(address, price)
        self.number_of_rooms = rooms

m = Mansion("Palm Street", 1000000, 10)
print(m.address, m.price, m.number_of_rooms)
# Out:
# Palm Street 1000000 10
